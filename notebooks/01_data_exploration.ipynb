# %% [markdown]
# # Data Exploration – GoEmotions
#
# This notebook explores the GoEmotions dataset to understand class distribution, text length, and dataset characteristics.

# %%
print('Notebook initialized successfully')
